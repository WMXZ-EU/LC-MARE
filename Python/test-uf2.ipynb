# %%
import serial
import serial.tools.list_ports

def getComPort():
    s=serial.tools.list_ports.comports(True)
    for ii in range(len(s)):
        if s[ii].vid==0x239a: 
            if (s[ii].pid==0x815d)  | (s[ii].pid==0x814f): 
                return s[ii].device
    return None

comPort=getComPort()
print(comPort)

# the following could be used if LC-MARE is downloaded via GitHub
program="adalogger_V3"
program_path="../"+program+"/build/rp2040.rp2040.adafruit_feather_adalogger/"+program+".ino.uf2"
cmd="python -I uf2conv.py -s "+comPort+" -f rp2040 -D "+program_path

import subprocess
# Execute a shell command
result = subprocess.run(cmd, shell=True, capture_output=True, text=True)

# Print the output
print("Output:\n", result.stdout)
print("Error:", result.stderr)
print("Return Code:", result.returncode)
# Out:
# None
# dir "../adalogger_V3/build/rp2040.rp2040.adafruit_feather_adalogger/adalogger_V3.ino.uf2"
# Output:
#   Volume in drive C is Windows
#  Volume Serial Number is 262C-EF0D
#
#  Directory of c:\Users\wzimm\Documents\GitHub\LC-MARE\adalogger_V3\build\rp2040.rp2040.adafruit_feather_adalogger
#
#
# Error: File Not Found
#
# Return Code: 1
